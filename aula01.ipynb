# %%
import pandas as pd

dados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true', compression = 'zip')

# %%
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# ## Desafio 01: Investigar por que a classe tratamento é tão desbalanceada?

# %%
dados['tratamento'].unique()
# Out:
# array(['com_droga', 'com_controle'], dtype=object)

# %% [markdown]
# A coluna tem apenas dois valores: com_droga e com_controle.

# %%
dados['tratamento'].value_counts()
# Out:
# com_droga       21948
# com_controle     1866
# Name: tratamento, dtype: int64

# %%
dados['tratamento'].value_counts()[1]
# Out:
# 1866

# %% [markdown]
# A classe está bem desbalanceada. Vamos ver a proporção.

# %%
dados['tratamento'].value_counts(normalize=True)
# Out:
# com_droga       0.921643
# com_controle    0.078357
# Name: tratamento, dtype: float64

# %%
import matplotlib.pyplot as plt

fig1, ax1 = plt.subplots()
valores = dados['tratamento'].value_counts()
labels = dados['tratamento'].unique()
explode = (0, 0.1)
ax1.pie(valores, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal') 
plt.tight_layout()
plt.show()

# %% [markdown]
# Vamos analisar os dados filtrando as observações que contêm os valores 'com_controle'.

# %%
df_com_controle = dados.query('tratamento == "com_controle"')
df_com_controle.head(10)
# Out:
#                id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 25   id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38   id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40   id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# 47   id_008a986b7  com_controle     48   D2  ... -0.4979  0.5281 -0.9245 -0.9367
# 63   id_009d8340f  com_controle     24   D2  ...  0.0949  0.2000 -0.4326  0.9364
# 81   id_00d575cfb  com_controle     72   D1  ...  0.6034  0.8906  1.0350  0.5739
# 96   id_010629f4f  com_controle     24   D2  ... -1.2790 -0.0619  0.5689  0.0263
# 117  id_0144e88e8  com_controle     48   D2  ...  0.1478  0.8284  0.2281  1.6320
# 133  id_018492dbc  com_controle     24   D2  ...  0.6527  1.1550  0.3270 -0.5111
# 148  id_01b05de6c  com_controle     48   D1  ...  0.2406  0.5057  0.8017  1.0280
#
# [10 rows x 877 columns]

# %% [markdown]
# A coluna de droga aparenta ter apenas um valor, vamos confirmar.

# %%
df_com_controle['droga'].unique()
# Out:
# array(['cacb2b860'], dtype=object)

# %% [markdown]
# Confirmamos que no tratamento com controle, apenas uma droga é administrada. É possivel que alguma droga ou placebo tenha sido administrado para controle.

# %% [markdown]
# ## Desafio 02: Plotar as 5 últimas linhas da tabela

# %%
dados.tail()
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# 23813  id_ffffdd77b     com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# [5 rows x 877 columns]

# %% [markdown]
# # Desafio 03: Proporção das classes tratamento.

# %%
dados['tratamento'].value_counts(normalize=True)*100
# Out:
# com_droga       92.164273
# com_controle     7.835727
# Name: tratamento, dtype: float64

# %%
import matplotlib.pyplot as plt

fig1, ax1 = plt.subplots()
valores = dados['tratamento'].value_counts()
labels = dados['tratamento'].unique()

cores = ['#66b3ff','#ffcc99']

ax1.pie(valores, colors = cores, labels=labels, autopct='%1.1f%%', startangle=90)

circulo_contral = plt.Circle((0,0),0.70,fc='white')
fig = plt.gcf()
fig.gca().add_artist(circulo_contral)

ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %% [markdown]
# # Desafio 04: Quantas tipos de drogas foram investigados.

# %%
dados['droga'].nunique()
# Out:
# 3289

# %% [markdown]
# 3289 drogas foram utilizadas.

# %% [markdown]
# # Desafio 05: Procurar na documentação o método query(pandas).

# %% [markdown]
# Link do método query: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.query.html

# %%
#Exemplo:

dados.query('tempo == "72"')
# Out:
#                  id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 1      id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 4      id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# 10     id_002452c7e  com_droga     72   D2  ...  0.6648  0.0651 -0.0125  0.2600
# 14     id_002d31e2c  com_droga     72   D1  ... -8.1330 -4.3170 -6.2390  0.9477
# 18     id_003603254  com_droga     72   D2  ... -1.3790 -0.4393 -0.0259  0.9765
# ...             ...        ...    ...  ...  ...     ...     ...     ...     ...
# 23797  id_ffe6452ba  com_droga     72   D2  ... -0.1795  0.0287  0.8309  1.1490
# 23798  id_fff11dbf5  com_droga     72   D2  ... -0.4231 -0.1848  0.5300 -0.1913
# 23800  id_fff1a3307  com_droga     72   D2  ...  0.3823  0.8707  0.8011  0.4942
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.7415  0.8413 -0.4259  0.2434
# 23813  id_ffffdd77b  com_droga     72   D1  ... -3.5770 -0.4775 -2.1500 -4.2520
#
# ...

# %% [markdown]
# # Desafio 06: Renomear as colunas tirando o hífen.

# %%
def remove_hifen(df):
  for i, val in enumerate(df.columns.values):
    if '-' in val:
      novo_nome = val.replace('-', '')
      df.columns.values[i] = novo_nome

# %%
remove_hifen(dados)

dados.head()
# Out:
#              id tratamento  tempo dose  ...     c96     c97     c98     c99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# # Desafio 07: Deixar os gráficos bonitões. (Matplotlib.pyplot)

# %%
plt.bar(dados['tratamento'].unique(), list(dados['tratamento'].value_counts()))
plt.title('Tratamentos utilizados no experimento')
plt.xlabel('Tratamentos')
plt.ylabel('Quantidade de observações')
plt.show()

# %%
dados['tempo'].value_counts().sort_index().plot.bar()
plt.title('Tempo de Analise - em horas')
plt.xlabel('Tempo de Analise')
plt.ylabel('Quantidade de experimentos')
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

fig1, ax1 = plt.subplots()
valores = dados['tratamento'].value_counts()
labels = dados['tratamento'].unique()
explode = (0, 0.1)
ax1.pie(valores, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)

ax1.axis('equal') 
plt.tight_layout()
plt.show()

# %% [markdown]
# # Desafio 08: Resumo do que você aprendeu com os dados

# %% [markdown]
# O tratamento mais utilizado no experimento foi com drogas. 3289 drogas foram utilizadas, sendo que apenas uma é administrada quando o tratamento é com controle.

# %%
dados.loc[dados['dose'] == 'D1'].shape
# Out:
# (12147, 877)

# %%
dados.loc[dados['dose'] == 'D2'].shape
# Out:
# (11667, 877)

# %%
dados['tempo'].unique()
# Out:
# array([24, 72, 48])

# %% [markdown]
# A quantidade de doses administradas foram maiores para D1 que D2 e foram utilizados os tempos de 24, 48 e 72 horas para administrar as doses.
